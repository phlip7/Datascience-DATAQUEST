# %% [markdown]
# ##    Importing Libraries And Exploring the Dataset

# %%
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
#print(recent_grads.head())
#print(recent_grads.tail())


#the number of rows in recent_grads
## raw_data_count = len(recent_grads.index)
rows, columns = recent_grads.shape
raw_data_count = rows
print("raw_data_count : "+str(raw_data_count))

#drop rows containing missing values
recent_grads = recent_grads.dropna()

rows, columns = recent_grads.shape
cleaned_data_count = rows

print("cleaned_data_count : "+str(cleaned_data_count))
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %% [markdown]
# ##    Pandas, Scatter Plots

# %%
#Relations between Sample_size and Median
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Sample_size vs Median", figsize=(5,5))

# %%
#Relations between Sample_size and Unemployment_rate
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Sample_size vs Unemployment_rate", figsize=(5,5))

# %%
#Relations between Full_time and Median
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full_time vs Median", figsize=(5,5))

# %%
#Relations between ShareWomen and Unemployment_rate
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter", title="ShareWomen vs Unemployment_rate", figsize=(5,5))

# %%
#Relations between Men and Median
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Men vs Median", figsize=(5,5))

# %%
#Relations between Women and Median
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women vs Median", figsize=(5,5))

# %% [markdown]
# ##    Pandas, Histograms

# %%
#Exploring the distribution of the following Sample_size, Median, Employed, Full_time, ShareWomen, Unemployment_rate, Men, Women

recent_grads["Sample_size"].hist(bins=25, range=(0,5000))

# %%
recent_grads["Median"].hist(bins=30000, range=(0,100000))

# %%
recent_grads["Employed"].hist(bins=25, range=(0,5000))

# %%
recent_grads["Full_time"].hist(bins=25, range=(0,5000))

# %%
recent_grads["ShareWomen"].hist(bins=25, range=(0,5000))

# %%
recent_grads["Unemployment_rate"].hist(bins=25, range=(0,5000))

# %%
recent_grads["Men"].hist(bins=25, range=(0,5000))

# %%
recent_grads["Women"].hist(bins=50, range=(0,5000))

# %% [markdown]
# ##    Pandas, Scatter Matrix Plot
#
# A scatter matrix plots are frequently used in the exploratory data analysis.
# A scatter matrix plot combines both scatter plots and histograms into one grid of plots and allows us to explore potential relationships and distributions simultaneously. A scatter matrix plot consists of n by n plots on a grid, where n is the number of columns, the plots on the diagonal are histograms, and the non-diagonal plots are scatter plots.

# %%
from pandas.tools.plotting import scatter_matrix

#2 by 2 scatter matrix plot using the Sample_size and Median columns
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9ebf8ffd0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fba006b87f0>]], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

#3 by 3 scatter matrix plot using the Sample_size, Median, and Unemployment_rate columns
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fb9ffbed518>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fb9fd864ef0>]], dtype=object)

# %% [markdown]
# ##    Pandas, Bar Plots

# %%
#compare the percentages of women (ShareWomen) from the 10 highest paying majors and from the 10 lowest paying majors
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)
